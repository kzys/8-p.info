# %% [markdown]
# # Looking back the past year through Hacker News
#
# This is the redo of something I did in [2018](https://blog.8-p.info/en/2018/01/01/hacker-news-2017/) which was heavily inspired by [Deedy Das's work in 2015](http://debarghyadas.com/writes/looking-back-at-9-years-of-hacker-news/). Apparently I did that in [2020](https://github.com/kzys/blog/blob/master/en/nb/2020/hn-2019.ipynb) again, but haven't been published anywhere.
#
# First let's adjust pandas a bit, since the default is too narrow to show URLs.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Then load `%%bigquery` magic from [google-cloud-bigquery](https://pypi.org/project/google-cloud-bigquery/). There was `%%bq`, but it was backed by [Datalab](https://cloud.google.com/bigquery/docs/datalab-migration) which was [deprecated](https://cloud.google.com/datalab/docs).

# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# For folks mostly use AWS, Google Cloud has a notion of "projects".

# %%
project_id = 'sandbox-374004'
params = {"year": 2022}

# %% [markdown]
# ## Most Upvoted Stories
#
# The below are the most upvoted stories. This could be "wow, that should be upvoted, but I don't have much to say" list.

# %%
# %%bigquery --params $params --project $project_id
# SELECT title, timestamp, `by`, score, descendants as comments, url, id FROM `bigquery-public-data.hacker_news.full`
# WHERE type = 'story' AND extract(year FROM timestamp) = @year
# ORDER BY score DESC LIMIT 20
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                                                title  \
# 0                                                                   Mechanical Watch
# 1                                                             Google Search Is Dying
# 2                                                       My First Impressions of Web3
# 3                                                                              Sound
# 4                                                                                GPS
# 5                                                        Queen Elizabeth II has died
# 6   Google no longer producing high quality search results in significant categories
# 7                       Elon Musk makes $43B unsolicited bid to take Twitter private
# 8                                  Twitter set to accept Musk's $43B offer – sources
# 9                                     Nvidia releases open-source GPU kernel modules
# 10                                                   Adobe to acquire Figma for $20B
# 11                           Russian forces invade Ukraine after Putin orders attack
# 12                                                    Someone is pretending to be me
# 13               US Senate votes unanimously to make daylight savings time permanent
# 14                                                    Google is shutting down Stadia
# 15                                          Microsoft to Acquire Activision Blizzard
# 16            Ask HN: What are some cool but obscure data structures you know about?
# 17                                                       Meta lays off 11,000 people
# 18                                                      I regret my website redesign
# 19                                                                           Bubbles
#
#                    timestamp             by  score  comments  \
# 0  2022-05-04 15:06:41+00:00   todsacerdoti   4298       413
# 1  2022-02-15 15:29:20+00:00      dbrereton   3636      1561
# 2  2022-01-07 21:41:56+00:00       natdempk   3393      1129
# 3  2022-10-18 15:48:16+00:00   todsacerdoti   3053       207
# 4  2022-01-18 16:06:04+00:00   todsacerdoti   2900       285
# 5  2022-09-08 17:33:02+00:00             xd   2827      1596
# 6  2022-01-02 18:50:38+00:00      lando2319   2813      1275
# 7  2022-04-14 10:24:06+00:00           zegl   2747      3078
# 8  2022-04-25 11:58:20+00:00         marban   2498      3678
# 9  2022-05-11 19:59:46+00:00      ghishadow   2410       392
# 10 2022-09-15 11:32:25+00:00       caoxuwen   2348      1246
# 11 2022-02-24 04:38:23+00:00            eis   2278      1814
# 12 2022-09-27 15:50:01+00:00    iBotPeaches   2244       382
# 13 2022-03-15 18:29:09+00:00  enraged_camel   2191      2218
# 14 2022-09-29 16:17:10+00:00        vyrotek   2090      1712
# 15 2022-01-18 13:30:22+00:00   totablebanjo   2051      1353
# 16 2022-07-21 22:50:29+00:00       Uptrenda   2051       753
# 17 2022-11-09 11:11:01+00:00    technics256   2046      1975
# 18 2022-07-21 14:06:31+00:00        mtlynch   2011       749
# 19 2022-11-11 21:12:48+00:00       findhorn   1975       174
#
#                                                                                                                                                          url  \
# 0                                                                                                                    https://ciechanow.ski/mechanical-watch/
# 1                                                                                                                 https://dkb.io/post/google-search-is-dying
# 2                                                                                                   https://moxie.org/2022/01/07/web3-first-impressions.html
# 3                                                                                                                               https://ciechanow.ski/sound/
# 4                                                                                                                                 https://ciechanow.ski/gps/
# 5                                                                                                                       https://www.bbc.com/news/uk-61585886
# 6                                                                                                    https://twitter.com/mwseibel/status/1477701120319361026
# 7                                               https://www.bloomberg.com/news/articles/2022-04-14/elon-musk-launches-43-billion-hostile-takeover-of-twitter
# 8                                                 https://www.reuters.com/technology/exclusive-twitter-set-accept-musks-best-final-offer-sources-2022-04-25/
# 9                                                                          https://developer.nvidia.com/blog/nvidia-releases-open-source-gpu-kernel-modules/
# 10                                          https://www.bloomberg.com/news/articles/2022-09-15/adobe-is-said-to-near-deal-to-buy-online-design-startup-figma
# 11                                   https://www.reuters.com/world/europe/putin-orders-military-operations-ukraine-demands-kyiv-forces-surrender-2022-02-24/
# 12                                                                                    https://connortumbleson.com/2022/09/19/someone-is-pretending-to-be-me/
# 13                                                                                            https://twitter.com/senatecloakroom/status/1503797632745025542
# 14                                                       https://www.theverge.com/2022/9/29/23378713/google-stadia-shutting-down-game-streaming-january-2023
# 15  https://news.microsoft.com/2022/01/18/microsoft-to-acquire-activision-blizzard-to-bring-the-joy-and-community-of-gaming-to-everyone-across-every-device/
# 16                                                                                                                                                      None
# 17                                                                            https://about.fb.com/news/2022/11/mark-zuckerberg-layoff-message-to-employees/
# 18                                                                                                                    https://mtlynch.io/tinypilot-redesign/
# 19                                                                                                                            https://oimo.io/works/bubbles/
#
#           id
# 0   31261533
# 1   30347719
# 2   29845208
# 3   33249215
# 4   29981188
# 5   32768834
# 6   29772136
# 7   31025061
# 8   31153277
# 9   31344981
# 10  32850178
# 11  30450336
# 12  32996953
# 13  30689043
# 14  33022768
# 15  29978723
# 16  32186203
# 17  33529838
# 18  32179563
# 19  33566924

# %% [markdown]
# ## Most Commented Stories
#
# Then the below are most commented stories. People don't nessesary upvote stories like Roe vs. Wade and/or Elon/Twitter drama, but have a lot to say.

# %%
# %%bigquery --params $params --project $project_id
# SELECT title, timestamp, `by`, score, descendants as comments, url, id FROM `bigquery-public-data.hacker_news.full`
# WHERE type = 'story' AND extract(year FROM timestamp) = @year
# ORDER BY comments DESC LIMIT 20
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                                               title  \
# 0                                 Twitter set to accept Musk's $43B offer – sources
# 1                                              Supreme Court Overturns Roe vs. Wade
# 2                      Elon Musk makes $43B unsolicited bid to take Twitter private
# 3               US Senate votes unanimously to make daylight savings time permanent
# 4                                                 Twitter’s mass layoffs have begun
# 5                                                       Meta lays off 11,000 people
# 6                                            Ask HN: What game do you wish existed?
# 7                                             Namecheap: Russia Service Termination
# 8                           Russian forces invade Ukraine after Putin orders attack
# 9                                          Elon Musk owns Twitter: The story so far
# 10              SpaceX said to fire employees involved in letter rebuking Elon Musk
# 11                              More Americans are saying they’re ‘vaxxed and done’
# 12                                                   Google is shutting down Stadia
# 13     Mental illness, mass shootings, and the politics of American firearms (2015)
# 14                                            Spotify deletes 70 Joe Rogan episodes
# 15  Tesla engineers were on-site to evaluate the Twitter staff’s code, workers said
# 16                                                               Blocking Kiwifarms
# 17                                                      Queen Elizabeth II has died
# 18                                                           Google Search Is Dying
# 19                                                       The Ethereum merge is done
#
#                    timestamp              by  score  comments  \
# 0  2022-04-25 11:58:20+00:00          marban   2498      3678
# 1  2022-06-24 14:18:37+00:00          uptown   1765      3463
# 2  2022-04-14 10:24:06+00:00            zegl   2747      3078
# 3  2022-03-15 18:29:09+00:00   enraged_camel   2191      2218
# 4  2022-11-04 09:33:25+00:00     matthieu_bl   1039      2117
# 5  2022-11-09 11:11:01+00:00     technics256   2046      1975
# 6  2022-05-25 11:50:35+00:00        jharohit    859      1839
# 7  2022-02-28 20:38:16+00:00         exizt88   1735      1828
# 8  2022-02-24 04:38:23+00:00             eis   2278      1814
# 9  2022-10-28 17:50:05+00:00          jiwidi    898      1796
# 10 2022-06-17 06:51:40+00:00           danso    614      1784
# 11 2022-01-10 18:09:50+00:00           nkurz    491      1725
# 12 2022-09-29 16:17:10+00:00         vyrotek   2090      1712
# 13 2022-05-25 22:04:26+00:00  LoveGracePeace    280      1678
# 14 2022-02-05 03:09:30+00:00  Acrobatic_Road    930      1677
# 15 2022-10-29 20:36:05+00:00     perihelions    607      1663
# 16 2022-09-03 22:17:41+00:00           _vvaw    994      1633
# 17 2022-09-08 17:33:02+00:00              xd   2827      1596
# 18 2022-02-15 15:29:20+00:00       dbrereton   3636      1561
# 19 2022-09-15 06:47:17+00:00       mfiguiere   1407      1549
#
#                                                                                                                         url  \
# 0                https://www.reuters.com/technology/exclusive-twitter-set-accept-musks-best-final-offer-sources-2022-04-25/
# 1                               https://apnews.com/article/abortion-supreme-court-decision-854f60302f21c2c35129e58cf8d8a7b0
# 2              https://www.bloomberg.com/news/articles/2022-04-14/elon-musk-launches-43-billion-hostile-takeover-of-twitter
# 3                                                            https://twitter.com/senatecloakroom/status/1503797632745025542
# 4                                                              https://techcrunch.com/2022/11/03/twitter-layoffs-elon-musk/
# 5                                            https://about.fb.com/news/2022/11/mark-zuckerberg-layoff-message-to-employees/
# 6                                                                                                                      None
# 7                                                                                                                      None
# 8   https://www.reuters.com/world/europe/putin-orders-military-operations-ukraine-demands-kyiv-forces-surrender-2022-02-24/
# 9                                                https://techcrunch.com/2022/10/28/elon-musk-owns-twitter-the-story-so-far/
# 10                                    https://www.nytimes.com/2022/06/17/technology/spacex-employees-fired-musk-letter.html
# 11                             https://www.theatlantic.com/ideas/archive/2022/01/covid-omicron-vaccination-rashomon/621199/
# 12                      https://www.theverge.com/2022/9/29/23378713/google-stadia-shutting-down-game-streaming-january-2023
# 13                                                                    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4318286/
# 14                                                                                              https://www.jremissing.com/
# 15                                         https://www.washingtonpost.com/technology/2022/10/29/elon-musk-twitter-takeover/
# 16                                                                           https://blog.cloudflare.com/kiwifarms-blocked/
# 17                                                                                     https://www.bbc.com/news/uk-61585886
# 18                                                                               https://dkb.io/post/google-search-is-dying
# 19                                         https://www.coindesk.com/tech/2022/09/15/the-ethereum-merge-is-done-did-it-work/
#
#           id
# 0   31153277
# 1   31862258
# 2   31025061
# 3   30689043
# 4   33463908
# 5   33529838
# 6   31503201
# 7   30504812
# 8   30450336
# 9   33374770
# 10  31774890
# 11  29878895
# 12  33022768
# 13  31511274
# 14  30216740
# 15  33387722
# 16  32706673
# 17  32768834
# 18  30347719
# 19  32848010
